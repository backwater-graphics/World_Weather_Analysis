# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import API Weather Key 
import requests
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?&units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
weather_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
        try:
            rain_inches = city_weather["rain"]["3h"]
        except:
            rain_inches = ("0")
            pass
        try:
            snow_inches = city_weather["snow"]["3h"]
        except:
            snow_inches = ("0")  
            pass
        
      
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into weather_data list.
        weather_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                           "Current Description": weather_description})

# If an error is experienced, skip the city.
    except Exception as e:
        print(e)
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | meulaboh
# Processing Record 2 of Set 1 | khatanga
# Processing Record 3 of Set 1 | kodiak
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | namibe
# Processing Record 6 of Set 1 | saint-joseph
# Processing Record 7 of Set 1 | sezemice
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | asosa
# Processing Record 11 of Set 1 | santa barbara
# Processing Record 12 of Set 1 | belushya guba
# 'coord'
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | morales
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | lolua
# 'coord'
# Processing Record 17 of Set 1 | lamesa
# Processing Record 18 of Set 1 | deputatskiy
# Processing Record 19 of Set 1 | geraldton
# Processing Record 20 of Set 1 | ilulissat
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | pringsewu
# Processing Record 24 of Set 1 | bataipora
# Processing Record 25 of Set 1 | airai
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | odweyne
# Processing Record 28 of Set 1 | sarangani
# Processing Record 29 of Set 1 | chokurdakh
# Processing Record 30 of Set 1 | sterling
# Processing Record 31 of Set 1 | domoni
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | ust-maya
# Processing Record 36 of Set 1 | cayenne
# Processing Record 37 of Set 1 | shimoda
# Processing Record 38 of Set 1 | gushikawa
# Processing Record 39 of Set 1 | nanortalik
# Processing Record 40 of Set 1 | amderma
# 'coord'
# Processing Record 41 of Set 1 | sarany
# Processing Record 42 of Set 1 | dhemaji
# Processing Record 43 of Set 1 | mahates
# Processing Record 44 of Set 1 | oranjestad
# Processing Record 45 of Set 1 | mys shmidta
# 'coord'
# Processing Record 46 of Set 1 | mehamn
# Processing Record 47 of Set 1 | ozark
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | karabash
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | busselton
# Processing Record 3 of Set 2 | kathu
# Processing Record 4 of Set 2 | raymondville
# Processing Record 5 of Set 2 | bima
# Processing Record 6 of Set 2 | hasaki
# Processing Record 7 of Set 2 | port moresby
# Processing Record 8 of Set 2 | sioux lookout
# Processing Record 9 of Set 2 | iqaluit
# Processing Record 10 of Set 2 | kapaa
# Processing Record 11 of Set 2 | mataura
# Processing Record 12 of Set 2 | gizo
# Processing Record 13 of Set 2 | sobolevo
# Processing Record 14 of Set 2 | svobodnyy
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | boyolangu
# Processing Record 17 of Set 2 | kargasok
# Processing Record 18 of Set 2 | hami
# Processing Record 19 of Set 2 | jinxiang
# Processing Record 20 of Set 2 | lorengau
# Processing Record 21 of Set 2 | talakan
# Processing Record 22 of Set 2 | dikson
# Processing Record 23 of Set 2 | mahebourg
# Processing Record 24 of Set 2 | sitka
# Processing Record 25 of Set 2 | faanui
# Processing Record 26 of Set 2 | marcona
# 'coord'
# Processing Record 27 of Set 2 | cidreira
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | camacupa
# Processing Record 30 of Set 2 | san policarpo
# Processing Record 31 of Set 2 | talnakh
# Processing Record 32 of Set 2 | dunedin
# Processing Record 33 of Set 2 | salalah
# Processing Record 34 of Set 2 | bethel
# Processing Record 35 of Set 2 | torbay
# Processing Record 36 of Set 2 | palana
# Processing Record 37 of Set 2 | sorland
# Processing Record 38 of Set 2 | beipiao
# Processing Record 39 of Set 2 | coquimbo
# Processing Record 40 of Set 2 | adrar
# Processing Record 41 of Set 2 | codrington
# Processing Record 42 of Set 2 | gornopravdinsk
# Processing Record 43 of Set 2 | nikolskoye
# Processing Record 44 of Set 2 | hobart
# Processing Record 45 of Set 2 | qingdao
# Processing Record 46 of Set 2 | qaanaaq
# Processing Record 47 of Set 2 | port lincoln
# Processing Record 48 of Set 2 | saint-philippe
# Processing Record 49 of Set 2 | skibbereen
# Processing Record 50 of Set 2 | longyearbyen
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | san quintin
# Processing Record 3 of Set 3 | touros
# Processing Record 4 of Set 3 | manitouwadge
# Processing Record 5 of Set 3 | araouane
# Processing Record 6 of Set 3 | finschhafen
# Processing Record 7 of Set 3 | pevek
# Processing Record 8 of Set 3 | ginir
# Processing Record 9 of Set 3 | illoqqortoormiut
# 'coord'
# Processing Record 10 of Set 3 | buchanan
# Processing Record 11 of Set 3 | hervey bay
# Processing Record 12 of Set 3 | namatanai
# Processing Record 13 of Set 3 | saldanha
# Processing Record 14 of Set 3 | tasiilaq
# Processing Record 15 of Set 3 | laguna
# Processing Record 16 of Set 3 | kyaikkami
# Processing Record 17 of Set 3 | nguiu
# 'coord'
# Processing Record 18 of Set 3 | upata
# Processing Record 19 of Set 3 | itarema
# Processing Record 20 of Set 3 | yulara
# Processing Record 21 of Set 3 | taolanaro
# 'coord'
# Processing Record 22 of Set 3 | sur
# Processing Record 23 of Set 3 | lyaskelya
# Processing Record 24 of Set 3 | marrakesh
# Processing Record 25 of Set 3 | tabou
# Processing Record 26 of Set 3 | matay
# Processing Record 27 of Set 3 | kahului
# Processing Record 28 of Set 3 | alofi
# Processing Record 29 of Set 3 | clyde river
# Processing Record 30 of Set 3 | campos belos
# Processing Record 31 of Set 3 | vieksniai
# Processing Record 32 of Set 3 | vagur
# Processing Record 33 of Set 3 | rzhev
# Processing Record 34 of Set 3 | madang
# Processing Record 35 of Set 3 | kuzino
# Processing Record 36 of Set 3 | port alfred
# Processing Record 37 of Set 3 | biltine
# Processing Record 38 of Set 3 | tiksi
# Processing Record 39 of Set 3 | kushiro
# Processing Record 40 of Set 3 | rio grande
# Processing Record 41 of Set 3 | katsuura
# Processing Record 42 of Set 3 | acapulco
# Processing Record 43 of Set 3 | aswan
# Processing Record 44 of Set 3 | nuevo casas grandes
# Processing Record 45 of Set 3 | samusu
# 'coord'
# Processing Record 46 of Set 3 | matara
# Processing Record 47 of Set 3 | butaritari
# Processing Record 48 of Set 3 | saint-gaudens
# Processing Record 49 of Set 3 | richmond hill
# Processing Record 50 of Set 3 | mandalgovi
# Processing Record 1 of Set 4 | lagoa
# Processing Record 2 of Set 4 | cape town
# Processing Record 3 of Set 4 | ahipara
# Processing Record 4 of Set 4 | maniitsoq
# Processing Record 5 of Set 4 | olonets
# Processing Record 6 of Set 4 | zhanatas
# 'coord'
# Processing Record 7 of Set 4 | paamiut
# Processing Record 8 of Set 4 | tsihombe
# 'coord'
# Processing Record 9 of Set 4 | castro
# Processing Record 10 of Set 4 | gat
# Processing Record 11 of Set 4 | apricena
# Processing Record 12 of Set 4 | kaitangata
# Processing Record 13 of Set 4 | grand centre
# 'coord'
# Processing Record 14 of Set 4 | bolungarvik
# 'coord'
# Processing Record 15 of Set 4 | udachnyy
# Processing Record 16 of Set 4 | puerto ayora
# Processing Record 17 of Set 4 | vardo
# Processing Record 18 of Set 4 | urengoy
# Processing Record 19 of Set 4 | walla walla
# Processing Record 20 of Set 4 | panama city
# Processing Record 21 of Set 4 | lata
# Processing Record 22 of Set 4 | sangar
# Processing Record 23 of Set 4 | yellowknife
# Processing Record 24 of Set 4 | quatre cocos
# Processing Record 25 of Set 4 | leningradskiy
# Processing Record 26 of Set 4 | bambous virieux
# Processing Record 27 of Set 4 | bonfim
# Processing Record 28 of Set 4 | viligili
# 'coord'
# Processing Record 29 of Set 4 | atar
# Processing Record 30 of Set 4 | umm lajj
# Processing Record 31 of Set 4 | allende
# Processing Record 32 of Set 4 | selma
# Processing Record 33 of Set 4 | hailar
# Processing Record 34 of Set 4 | pochutla
# Processing Record 35 of Set 4 | halalo
# 'coord'
# Processing Record 36 of Set 4 | bengkulu
# Processing Record 37 of Set 4 | saint george
# Processing Record 38 of Set 4 | shingu
# Processing Record 39 of Set 4 | ljubimec
# 'coord'
# Processing Record 40 of Set 4 | ust-ilimsk
# Processing Record 41 of Set 4 | bethanien
# Processing Record 42 of Set 4 | redmond
# Processing Record 43 of Set 4 | cabo san lucas
# Processing Record 44 of Set 4 | attawapiskat
# 'coord'
# Processing Record 45 of Set 4 | kusk
# 'coord'
# Processing Record 46 of Set 4 | merritt
# Processing Record 47 of Set 4 | inderborskiy
# 'coord'
# Processing Record 48 of Set 4 | guarapari
# Processing Record 49 of Set 4 | saskylakh
# Processing Record 50 of Set 4 | mushie
# Processing Record 1 of Set 5 | suez
# Processing Record 2 of Set 5 | karaul
# 'coord'
# Processing Record 3 of Set 5 | ostrovnoy
# Processing Record 4 of Set 5 | antalaha
# Processing Record 5 of Set 5 | constitucion
# Processing Record 6 of Set 5 | krasnoselkup
# Processing Record 7 of Set 5 | souillac
# Processing Record 8 of Set 5 | isiolo
# Processing Record 9 of Set 5 | afmadu
# 'coord'
# Processing Record 10 of Set 5 | avarua
# Processing Record 11 of Set 5 | hamilton
# Processing Record 12 of Set 5 | saint-pierre
# Processing Record 13 of Set 5 | upernavik
# Processing Record 14 of Set 5 | botevgrad
# Processing Record 15 of Set 5 | kiyasovo
# Processing Record 16 of Set 5 | kavieng
# Processing Record 17 of Set 5 | chuy
# Processing Record 18 of Set 5 | bandarbeyla
# Processing Record 19 of Set 5 | kalmunai
# Processing Record 20 of Set 5 | havre-saint-pierre
# Processing Record 21 of Set 5 | grindavik
# Processing Record 22 of Set 5 | haines junction
# Processing Record 23 of Set 5 | sorvag
# 'coord'
# Processing Record 24 of Set 5 | ust-karsk
# Processing Record 25 of Set 5 | ballina
# Processing Record 26 of Set 5 | rokytnice nad jizerou
# Processing Record 27 of Set 5 | kutahya
# Processing Record 28 of Set 5 | nador
# Processing Record 29 of Set 5 | thompson
# Processing Record 30 of Set 5 | acari
# Processing Record 31 of Set 5 | cananea
# Processing Record 32 of Set 5 | mahanje
# Processing Record 33 of Set 5 | karamay
# 'coord'
# Processing Record 34 of Set 5 | tuatapere
# Processing Record 35 of Set 5 | nova odesa
# Processing Record 36 of Set 5 | ponta do sol
# Processing Record 37 of Set 5 | nuevo ideal
# Processing Record 38 of Set 5 | victoria
# Processing Record 39 of Set 5 | sergeyevka
# Processing Record 40 of Set 5 | wonthaggi
# Processing Record 41 of Set 5 | nadym
# Processing Record 42 of Set 5 | tairua
# Processing Record 43 of Set 5 | halifax
# Processing Record 44 of Set 5 | arraial do cabo
# Processing Record 45 of Set 5 | dingle
# Processing Record 46 of Set 5 | samarai
# Processing Record 47 of Set 5 | komsomolskiy
# Processing Record 48 of Set 5 | berezovyy
# Processing Record 49 of Set 5 | antipovka
# Processing Record 50 of Set 5 | cedar city
# Processing Record 1 of Set 6 | filadelfia
# Processing Record 2 of Set 6 | vaini
# Processing Record 3 of Set 6 | nova olinda do norte
# Processing Record 4 of Set 6 | barreirinhas
# Processing Record 5 of Set 6 | port elizabeth
# Processing Record 6 of Set 6 | cravo norte
# Processing Record 7 of Set 6 | carnarvon
# Processing Record 8 of Set 6 | guerrero negro
# Processing Record 9 of Set 6 | evensk
# Processing Record 10 of Set 6 | aklavik
# Processing Record 11 of Set 6 | rudnichnyy
# Processing Record 12 of Set 6 | skwierzyna
# Processing Record 13 of Set 6 | saint stephen
# Processing Record 14 of Set 6 | sagua la grande
# Processing Record 15 of Set 6 | caravelas
# Processing Record 16 of Set 6 | bom conselho
# Processing Record 17 of Set 6 | nizhneyansk
# 'coord'
# Processing Record 18 of Set 6 | provideniya
# Processing Record 19 of Set 6 | gonen
# Processing Record 20 of Set 6 | lodwar
# Processing Record 21 of Set 6 | baykit
# Processing Record 22 of Set 6 | tura
# Processing Record 23 of Set 6 | monastyrshchina
# Processing Record 24 of Set 6 | mangrol
# Processing Record 25 of Set 6 | marsaxlokk
# Processing Record 26 of Set 6 | tabas
# Processing Record 27 of Set 6 | shimanovsk
# Processing Record 28 of Set 6 | conway
# Processing Record 29 of Set 6 | wake forest
# Processing Record 30 of Set 6 | anar darreh
# 'coord'
# Processing Record 31 of Set 6 | amberley
# Processing Record 32 of Set 6 | georgetown
# Processing Record 33 of Set 6 | narsaq
# Processing Record 34 of Set 6 | port stanley
# Processing Record 35 of Set 6 | vila franca do campo
# Processing Record 36 of Set 6 | alice springs
# Processing Record 37 of Set 6 | taunggyi
# Processing Record 38 of Set 6 | anadyr
# Processing Record 39 of Set 6 | crixas
# Processing Record 40 of Set 6 | payo
# Processing Record 41 of Set 6 | kattivakkam
# Processing Record 42 of Set 6 | wajima
# Processing Record 43 of Set 6 | katha
# 'coord'
# Processing Record 44 of Set 6 | mount gambier
# Processing Record 45 of Set 6 | mocajuba
# Processing Record 46 of Set 6 | cherskiy
# Processing Record 47 of Set 6 | oriximina
# Processing Record 48 of Set 6 | praia da vitoria
# Processing Record 49 of Set 6 | bendorf
# Processing Record 50 of Set 6 | kenai
# Processing Record 1 of Set 7 | pangnirtung
# Processing Record 2 of Set 7 | half moon bay
# Processing Record 3 of Set 7 | marienburg
# Processing Record 4 of Set 7 | svetlogorsk
# Processing Record 5 of Set 7 | zhangzhou
# Processing Record 6 of Set 7 | moiyabana
# 'coord'
# Processing Record 7 of Set 7 | mount isa
# Processing Record 8 of Set 7 | carballo
# Processing Record 9 of Set 7 | shelburne
# Processing Record 10 of Set 7 | cockburn town
# Processing Record 11 of Set 7 | lipari
# Processing Record 12 of Set 7 | sistranda
# Processing Record 13 of Set 7 | saleaula
# 'coord'
# Processing Record 14 of Set 7 | lhokseumawe
# Processing Record 15 of Set 7 | anloga
# Processing Record 16 of Set 7 | wana
# Processing Record 17 of Set 7 | batagay-alyta
# Processing Record 18 of Set 7 | port augusta
# Processing Record 19 of Set 7 | salvador
# Processing Record 20 of Set 7 | dodge city
# Processing Record 21 of Set 7 | naze
# Processing Record 22 of Set 7 | antalya
# Processing Record 23 of Set 7 | port keats
# Processing Record 24 of Set 7 | conceicao do araguaia
# Processing Record 25 of Set 7 | uige
# Processing Record 26 of Set 7 | kamenskoye
# 'coord'
# Processing Record 27 of Set 7 | ilhabela
# Processing Record 28 of Set 7 | maua
# Processing Record 29 of Set 7 | paradwip
# 'coord'
# Processing Record 30 of Set 7 | lokoja
# Processing Record 31 of Set 7 | karratha
# Processing Record 32 of Set 7 | bukachacha
# Processing Record 33 of Set 7 | ust-kan
# Processing Record 34 of Set 7 | faya
# Processing Record 35 of Set 7 | yar-sale
# Processing Record 36 of Set 7 | linjiang
# Processing Record 37 of Set 7 | santa maria
# Processing Record 38 of Set 7 | sentyabrskiy
# 'coord'
# Processing Record 39 of Set 7 | kampot
# Processing Record 40 of Set 7 | hangzhou
# Processing Record 41 of Set 7 | isangel
# Processing Record 42 of Set 7 | daitari
# Processing Record 43 of Set 7 | tabuk
# Processing Record 44 of Set 7 | sento se
# 'coord'
# Processing Record 45 of Set 7 | azul
# Processing Record 46 of Set 7 | camocim
# Processing Record 47 of Set 7 | vao
# Processing Record 48 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 7 | padang
# Processing Record 50 of Set 7 | sao filipe
# Processing Record 1 of Set 8 | chancay
# Processing Record 2 of Set 8 | lichuan
# Processing Record 3 of Set 8 | emba
# Processing Record 4 of Set 8 | shahr-e kord
# Processing Record 5 of Set 8 | portland
# Processing Record 6 of Set 8 | kununurra
# Processing Record 7 of Set 8 | fianarantsoa
# Processing Record 8 of Set 8 | marzuq
# Processing Record 9 of Set 8 | grand river south east
# 'coord'
# Processing Record 10 of Set 8 | the pas
# Processing Record 11 of Set 8 | fortuna
# Processing Record 12 of Set 8 | thinadhoo
# Processing Record 13 of Set 8 | paulista
# Processing Record 14 of Set 8 | khash
# Processing Record 15 of Set 8 | brigantine
# Processing Record 16 of Set 8 | shestakovo
# Processing Record 17 of Set 8 | ust-omchug
# Processing Record 18 of Set 8 | ugoofaaru
# Processing Record 19 of Set 8 | palabuhanratu
# 'coord'
# Processing Record 20 of Set 8 | maceio
# Processing Record 21 of Set 8 | aksay
# Processing Record 22 of Set 8 | cutro
# Processing Record 23 of Set 8 | kalanguy
# Processing Record 24 of Set 8 | pierre
# Processing Record 25 of Set 8 | husavik
# Processing Record 26 of Set 8 | lebu
# Processing Record 27 of Set 8 | dublin
# Processing Record 28 of Set 8 | pauini
# Processing Record 29 of Set 8 | pacific grove
# Processing Record 30 of Set 8 | peniche
# Processing Record 31 of Set 8 | shiyan
# Processing Record 32 of Set 8 | ancud
# Processing Record 33 of Set 8 | ravar
# Processing Record 34 of Set 8 | saryshagan
# 'coord'
# Processing Record 35 of Set 8 | hambantota
# Processing Record 36 of Set 8 | byron bay
# Processing Record 37 of Set 8 | barentsburg
# 'coord'
# Processing Record 38 of Set 8 | ngukurr
# 'coord'
# Processing Record 39 of Set 8 | comodoro rivadavia
# Processing Record 40 of Set 8 | rio gallegos
# Processing Record 41 of Set 8 | naryan-mar
# Processing Record 42 of Set 8 | ambovombe
# Processing Record 43 of Set 8 | ewa beach
# Processing Record 44 of Set 8 | arua
# Processing Record 45 of Set 8 | turukhansk
# Processing Record 46 of Set 8 | ust-nera
# Processing Record 47 of Set 8 | uvira
# Processing Record 48 of Set 8 | vila
# Processing Record 49 of Set 8 | la primavera
# Processing Record 50 of Set 8 | magadan
# Processing Record 1 of Set 9 | svetlaya
# Processing Record 2 of Set 9 | sataua
# 'coord'
# Processing Record 3 of Set 9 | valparaiso
# Processing Record 4 of Set 9 | erenhot
# Processing Record 5 of Set 9 | boueni
# Processing Record 6 of Set 9 | vokhma
# Processing Record 7 of Set 9 | vila velha
# Processing Record 8 of Set 9 | kirakira
# Processing Record 9 of Set 9 | esperance
# Processing Record 10 of Set 9 | tefe
# Processing Record 11 of Set 9 | lompoc
# Processing Record 12 of Set 9 | olga
# Processing Record 13 of Set 9 | jalu
# Processing Record 14 of Set 9 | nanakuli
# Processing Record 15 of Set 9 | abu kamal
# Processing Record 16 of Set 9 | kavaratti
# Processing Record 17 of Set 9 | tazovskiy
# Processing Record 18 of Set 9 | eregli
# Processing Record 19 of Set 9 | lerwick
# Processing Record 20 of Set 9 | leh
# Processing Record 21 of Set 9 | san julian
# Processing Record 22 of Set 9 | santa luzia
# Processing Record 23 of Set 9 | kachikau
# 'coord'
# Processing Record 24 of Set 9 | handan
# Processing Record 25 of Set 9 | goderich
# Processing Record 26 of Set 9 | severo-kurilsk
# Processing Record 27 of Set 9 | kulhudhuffushi
# Processing Record 28 of Set 9 | irati
# Processing Record 29 of Set 9 | porto novo
# Processing Record 30 of Set 9 | bukan
# Processing Record 31 of Set 9 | poquoson
# Processing Record 32 of Set 9 | labuhan
# Processing Record 33 of Set 9 | lahat
# Processing Record 34 of Set 9 | snezhnogorsk
# Processing Record 35 of Set 9 | kruisfontein
# Processing Record 36 of Set 9 | beyneu
# Processing Record 37 of Set 9 | bathsheba
# Processing Record 38 of Set 9 | sembe
# Processing Record 39 of Set 9 | datong
# Processing Record 40 of Set 9 | kanlagay
# Processing Record 41 of Set 9 | vikulovo
# Processing Record 42 of Set 9 | at-bashi
# Processing Record 43 of Set 9 | san nicola
# Processing Record 44 of Set 9 | bachatskiy
# Processing Record 45 of Set 9 | port hardy
# Processing Record 46 of Set 9 | jumla
# Processing Record 47 of Set 9 | the valley
# Processing Record 48 of Set 9 | mahina
# Processing Record 49 of Set 9 | mutsamudu
# 'coord'
# Processing Record 50 of Set 9 | union de san antonio
# Processing Record 1 of Set 10 | gilgit
# Processing Record 2 of Set 10 | eureka
# Processing Record 3 of Set 10 | garowe
# Processing Record 4 of Set 10 | port-gentil
# Processing Record 5 of Set 10 | knoxville
# Processing Record 6 of Set 10 | batangafo
# Processing Record 7 of Set 10 | tapaua
# 'coord'
# Processing Record 8 of Set 10 | kalangala
# Processing Record 9 of Set 10 | tubruq
# 'coord'
# Processing Record 10 of Set 10 | rocha
# Processing Record 11 of Set 10 | ngunguru
# Processing Record 12 of Set 10 | kralendijk
# Processing Record 13 of Set 10 | ko samui
# Processing Record 14 of Set 10 | sechura
# Processing Record 15 of Set 10 | chicama
# Processing Record 16 of Set 10 | chadiza
# Processing Record 17 of Set 10 | los llanos de aridane
# Processing Record 18 of Set 10 | nyurba
# Processing Record 19 of Set 10 | chapeco
# Processing Record 20 of Set 10 | rundu
# Processing Record 21 of Set 10 | imeni poliny osipenko
# Processing Record 22 of Set 10 | el alto
# Processing Record 23 of Set 10 | luderitz
# Processing Record 24 of Set 10 | hofn
# Processing Record 25 of Set 10 | kieta
# Processing Record 26 of Set 10 | gleisdorf
# Processing Record 27 of Set 10 | natchitoches
# Processing Record 28 of Set 10 | uyemskiy
# Processing Record 29 of Set 10 | lake havasu city
# Processing Record 30 of Set 10 | mahdasht
# Processing Record 31 of Set 10 | tabiauea
# 'coord'
# Processing Record 32 of Set 10 | guangyuan
# Processing Record 33 of Set 10 | kaka
# Processing Record 34 of Set 10 | atasu
# Processing Record 35 of Set 10 | dolores
# Processing Record 36 of Set 10 | hirara
# Processing Record 37 of Set 10 | ondorhaan
# 'coord'
# Processing Record 38 of Set 10 | sakakah
# Processing Record 39 of Set 10 | hobyo
# Processing Record 40 of Set 10 | henties bay
# Processing Record 41 of Set 10 | harper
# Processing Record 42 of Set 10 | makat
# Processing Record 43 of Set 10 | bulawayo
# Processing Record 44 of Set 10 | ninghai
# Processing Record 45 of Set 10 | metu
# Processing Record 46 of Set 10 | santa cruz del sur
# Processing Record 47 of Set 10 | aguilas
# Processing Record 48 of Set 10 | kuruman
# Processing Record 49 of Set 10 | lisakovsk
# Processing Record 50 of Set 10 | luganville
# Processing Record 1 of Set 11 | general pico
# Processing Record 2 of Set 11 | lakatoro
# Processing Record 3 of Set 11 | innisfail
# Processing Record 4 of Set 11 | coahuayana
# Processing Record 5 of Set 11 | stephenville
# Processing Record 6 of Set 11 | artyk
# 'coord'
# Processing Record 7 of Set 11 | esperanza
# Processing Record 8 of Set 11 | port macquarie
# Processing Record 9 of Set 11 | pak phanang
# Processing Record 10 of Set 11 | hoi an
# Processing Record 11 of Set 11 | cooma
# Processing Record 12 of Set 11 | misratah
# Processing Record 13 of Set 11 | chikhli
# Processing Record 14 of Set 11 | polson
# Processing Record 15 of Set 11 | sept-iles
# Processing Record 16 of Set 11 | gobabis
# Processing Record 17 of Set 11 | kurikka
# Processing Record 18 of Set 11 | micheweni
# Processing Record 19 of Set 11 | oranjemund
# Processing Record 20 of Set 11 | constantine
# Processing Record 21 of Set 11 | buta
# Processing Record 22 of Set 11 | townsville
# Processing Record 23 of Set 11 | berlevag
# Processing Record 24 of Set 11 | krasnogorsk
# Processing Record 25 of Set 11 | tiarei
# Processing Record 26 of Set 11 | utete
# Processing Record 27 of Set 11 | prince rupert
# Processing Record 28 of Set 11 | norman wells
# Processing Record 29 of Set 11 | poum
# Processing Record 30 of Set 11 | mount pleasant
# Processing Record 31 of Set 11 | oarai
# Processing Record 32 of Set 11 | fort-shevchenko
# Processing Record 33 of Set 11 | sinnamary
# Processing Record 34 of Set 11 | asau
# Processing Record 35 of Set 11 | dakar
# Processing Record 36 of Set 11 | kibre mengist
# Processing Record 37 of Set 11 | pasni
# Processing Record 38 of Set 11 | taoudenni
# Processing Record 39 of Set 11 | general roca
# Processing Record 40 of Set 11 | geresk
# 'coord'
# Processing Record 41 of Set 11 | nantou
# Processing Record 42 of Set 11 | palmer
# Processing Record 43 of Set 11 | hibbing
# Processing Record 44 of Set 11 | oktyabrskiy
# Processing Record 45 of Set 11 | borogontsy
# Processing Record 46 of Set 11 | paucartambo
# 'coord'
# Processing Record 47 of Set 11 | novyy urgal
# Processing Record 48 of Set 11 | tsogni
# Processing Record 49 of Set 11 | olafsvik
# Processing Record 50 of Set 11 | qasigiannguit
# Processing Record 1 of Set 12 | deep river
# Processing Record 2 of Set 12 | sao joao da barra
# Processing Record 3 of Set 12 | shache
# Processing Record 4 of Set 12 | dzhebariki-khaya
# Processing Record 5 of Set 12 | houma
# Processing Record 6 of Set 12 | penalva
# Processing Record 7 of Set 12 | yaguachi
# Processing Record 8 of Set 12 | starobaltachevo
# Processing Record 9 of Set 12 | olinda
# Processing Record 10 of Set 12 | maputo
# Processing Record 11 of Set 12 | les cayes
# Processing Record 12 of Set 12 | kubachi
# Processing Record 13 of Set 12 | langres
# Processing Record 14 of Set 12 | puteyets
# Processing Record 15 of Set 12 | pangai
# Processing Record 16 of Set 12 | kalakamati
# Processing Record 17 of Set 12 | azimur
# 'coord'
# Processing Record 18 of Set 12 | colares
# Processing Record 19 of Set 12 | mahibadhoo
# Processing Record 20 of Set 12 | chateaubelair
# Processing Record 21 of Set 12 | mombetsu
# Processing Record 22 of Set 12 | plettenberg bay
# Processing Record 23 of Set 12 | totness
# Processing Record 24 of Set 12 | wanning
# Processing Record 25 of Set 12 | amparai
# 'coord'
# Processing Record 26 of Set 12 | san juan
# Processing Record 27 of Set 12 | shakawe
# Processing Record 28 of Set 12 | luena
# Processing Record 29 of Set 12 | sheltozero
# Processing Record 30 of Set 12 | darhan
# Processing Record 31 of Set 12 | ushtobe
# Processing Record 32 of Set 12 | tamiahua
# Processing Record 33 of Set 12 | nishihara
# Processing Record 34 of Set 12 | rungata
# 'coord'
# Processing Record 35 of Set 12 | kargil
# Processing Record 36 of Set 12 | ullapool
# Processing Record 37 of Set 12 | zhigansk
# Processing Record 38 of Set 12 | huilong
# Processing Record 39 of Set 12 | bilibino
# Processing Record 40 of Set 12 | beringovskiy
# Processing Record 41 of Set 12 | nantucket
# Processing Record 42 of Set 12 | ankang
# Processing Record 43 of Set 12 | kazalinsk
# 'coord'
# Processing Record 44 of Set 12 | vaitupu
# 'coord'
# Processing Record 45 of Set 12 | grand forks
# Processing Record 46 of Set 12 | zahir pir
# Processing Record 47 of Set 12 | lakes entrance
# Processing Record 48 of Set 12 | cordele
# Processing Record 49 of Set 12 | darnah
# Processing Record 50 of Set 12 | podbelsk
# 'coord'
# Processing Record 1 of Set 13 | myaundzha
# Processing Record 2 of Set 13 | iskateley
# Processing Record 3 of Set 13 | ayagoz
# Processing Record 4 of Set 13 | san patricio
# Processing Record 5 of Set 13 | srednekolymsk
# Processing Record 6 of Set 13 | port hawkesbury
# Processing Record 7 of Set 13 | ouahigouya
# Processing Record 8 of Set 13 | axim
# Processing Record 9 of Set 13 | pisco
# Processing Record 10 of Set 13 | calbuco
# Processing Record 11 of Set 13 | myitkyina
# Processing Record 12 of Set 13 | tumannyy
# 'coord'
# Processing Record 13 of Set 13 | little current
# Processing Record 14 of Set 13 | rosita
# Processing Record 15 of Set 13 | mullovka
# Processing Record 16 of Set 13 | laerdalsoyri
# Processing Record 17 of Set 13 | aden
# Processing Record 18 of Set 13 | galveston
# Processing Record 19 of Set 13 | santa rosa
# Processing Record 20 of Set 13 | aykhal
# Processing Record 21 of Set 13 | farah
# Processing Record 22 of Set 13 | storforshei
# Processing Record 23 of Set 13 | gambela
# Processing Record 24 of Set 13 | nouadhibou
# Processing Record 25 of Set 13 | road town
# Processing Record 26 of Set 13 | zyryanka
# Processing Record 27 of Set 13 | aksarka
# Processing Record 28 of Set 13 | iraquara
# Processing Record 29 of Set 13 | medea
# Processing Record 30 of Set 13 | flinders
# Processing Record 31 of Set 13 | barra do garcas
# Processing Record 32 of Set 13 | opuwo
# Processing Record 33 of Set 13 | tromso
# Processing Record 34 of Set 13 | safwah
# 'coord'
# Processing Record 35 of Set 13 | puerto escondido
# Processing Record 36 of Set 13 | broken hill
# Processing Record 37 of Set 13 | korhogo
# Processing Record 38 of Set 13 | zhuanghe
# Processing Record 39 of Set 13 | qandala
# Processing Record 40 of Set 13 | mbabane
# Processing Record 41 of Set 13 | huehuetan
# Processing Record 42 of Set 13 | birao
# Processing Record 43 of Set 13 | rakiv lis
# Processing Record 44 of Set 13 | manakara
# Processing Record 45 of Set 13 | nouakchott
# Processing Record 46 of Set 13 | gadwal
# Processing Record 47 of Set 13 | port blair
# Processing Record 48 of Set 13 | katherine
# Processing Record 49 of Set 13 | quang ngai
# Processing Record 50 of Set 13 | yaan
# Processing Record 1 of Set 14 | sideropolis
# Processing Record 2 of Set 14 | kothen
# Processing Record 3 of Set 14 | baherden
# Processing Record 4 of Set 14 | alta floresta
# Processing Record 5 of Set 14 | klaksvik
# Processing Record 6 of Set 14 | tezu
# Processing Record 7 of Set 14 | alghero
# Processing Record 8 of Set 14 | rey bouba
# Processing Record 9 of Set 14 | mudyuga
# 'coord'
# Processing Record 10 of Set 14 | kupang
# Processing Record 11 of Set 14 | lavrentiya
# Processing Record 12 of Set 14 | andros town
# Processing Record 13 of Set 14 | mamallapuram
# Processing Record 14 of Set 14 | daru
# Processing Record 15 of Set 14 | najran
# Processing Record 16 of Set 14 | batala
# Processing Record 17 of Set 14 | solsvik
# 'coord'
# Processing Record 18 of Set 14 | caraquet
# Processing Record 19 of Set 14 | auki
# Processing Record 20 of Set 14 | ust-tsilma
# Processing Record 21 of Set 14 | noumea
# Processing Record 22 of Set 14 | rawannawi
# 'coord'
# Processing Record 23 of Set 14 | hay river
# Processing Record 24 of Set 14 | purwodadi
# Processing Record 25 of Set 14 | khonuu
# 'coord'
# Processing Record 26 of Set 14 | mentok
# 'coord'
# Processing Record 27 of Set 14 | manikling
# Processing Record 28 of Set 14 | san cristobal
# Processing Record 29 of Set 14 | moron
# Processing Record 30 of Set 14 | botwood
# Processing Record 31 of Set 14 | sindand
# 'coord'
# Processing Record 32 of Set 14 | la huacana
# Processing Record 33 of Set 14 | charters towers
# Processing Record 34 of Set 14 | moree
# Processing Record 35 of Set 14 | xiuyan
# Processing Record 36 of Set 14 | bahia blanca
# Processing Record 37 of Set 14 | sao felix do xingu
# Processing Record 38 of Set 14 | otjimbingwe
# Processing Record 39 of Set 14 | barbalha
# Processing Record 40 of Set 14 | malakal
# Processing Record 41 of Set 14 | taltal
# Processing Record 42 of Set 14 | charagua
# Processing Record 43 of Set 14 | tecoanapa
# Processing Record 44 of Set 14 | riyadh
# Processing Record 45 of Set 14 | vestmannaeyjar
# Processing Record 46 of Set 14 | bilma
# Processing Record 47 of Set 14 | swindon
# Processing Record 48 of Set 14 | wichian buri
# Processing Record 49 of Set 14 | honiara
# Processing Record 50 of Set 14 | makakilo city
# Processing Record 1 of Set 15 | luancheng
# Processing Record 2 of Set 15 | puri
# Processing Record 3 of Set 15 | tigil
# Processing Record 4 of Set 15 | chapais
# Processing Record 5 of Set 15 | maragogi
# Processing Record 6 of Set 15 | asyut
# Processing Record 7 of Set 15 | waw
# Processing Record 8 of Set 15 | virginia beach
# Processing Record 9 of Set 15 | conakry
# Processing Record 10 of Set 15 | ocampo
# Processing Record 11 of Set 15 | pithora
# Processing Record 12 of Set 15 | chumphon
# Processing Record 13 of Set 15 | korla
# Processing Record 14 of Set 15 | trairi
# Processing Record 15 of Set 15 | subate
# Processing Record 16 of Set 15 | tuggurt
# 'coord'
# Processing Record 17 of Set 15 | marivan
# Processing Record 18 of Set 15 | north myrtle beach
# Processing Record 19 of Set 15 | pindorama
# Processing Record 20 of Set 15 | puerto ayacucho
# Processing Record 21 of Set 15 | george
# Processing Record 22 of Set 15 | vostok
# Processing Record 23 of Set 15 | grants
# Processing Record 24 of Set 15 | bajo baudo
# 'coord'
# Processing Record 25 of Set 15 | cavalcante
# Processing Record 26 of Set 15 | adeje
# Processing Record 27 of Set 15 | buraydah
# Processing Record 28 of Set 15 | inhambane
# Processing Record 29 of Set 15 | roald
# Processing Record 30 of Set 15 | moyale
# Processing Record 31 of Set 15 | mezen
# Processing Record 32 of Set 15 | mae sai
# Processing Record 33 of Set 15 | seymchan
# Processing Record 34 of Set 15 | shenjiamen
# Processing Record 35 of Set 15 | bereda
# Processing Record 36 of Set 15 | huarmey
# Processing Record 37 of Set 15 | trondheim
# Processing Record 38 of Set 15 | ormara
# Processing Record 39 of Set 15 | tachov
# Processing Record 40 of Set 15 | bang saphan
# Processing Record 41 of Set 15 | fare
# Processing Record 42 of Set 15 | springdale
# Processing Record 43 of Set 15 | kasane
# Processing Record 44 of Set 15 | sabile
# Processing Record 45 of Set 15 | kita
# Processing Record 46 of Set 15 | ajdabiya
# Processing Record 47 of Set 15 | manyana
# Processing Record 48 of Set 15 | vanimo
# Processing Record 49 of Set 15 | utiel
# Processing Record 50 of Set 15 | nurota
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
weather_data_df = pd.DataFrame(weather_data)
weather_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Meulaboh      ID   4.1363   96.1285     83.48        76          70
# 1      Khatanga      RU  71.9667  102.5000     -6.86        96         100
# 2        Kodiak      US  57.7900 -152.4072     26.11        74         100
# 3  Punta Arenas      CL -53.1500  -70.9167     59.11        44         100
# 4        Namibe      AO -15.1961   12.1522     70.86        83         100
# 5  Saint-Joseph      RE -21.3667   55.6167     79.11        71           0
# 6      Sezemice      CZ  50.0665   15.8527     36.41        67           0
# 7          Hilo      US  19.7297 -155.0900     74.25        86           4
# 8         Bluff      NZ -46.6000  168.3333     67.80        63          91
# 9         Asosa      ET  10.0667   34.5333     58.93        49           0
#
#    Wind Speed Current Description
# 0        3.89       broken clouds
# 1        6.67     overcast clouds
# 2       19.57          light snow
# 3        5.99     overcast clouds
# 4        6.26     overcast clouds
# 5        7.00           clear sky
# 6        3.00           clear sky
# 7        3.00           clear sky
# 8        8.05     overcast clouds
# 9        6.20           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the weather_Data into a CSV.
weather_data_df.to_csv(output_data_file, index_label="City_ID")
